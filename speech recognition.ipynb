# %%
# !pip install speechrecognition pyttsx3 wikipedia-api
# Out:
# Requirement already satisfied: speechrecognition in c:\users\257380\anaconda3\lib\site-packages (3.14.2)
# Requirement already satisfied: pyttsx3 in c:\users\257380\anaconda3\lib\site-packages (2.98)
# Requirement already satisfied: wikipedia-api in c:\users\257380\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: typing-extensions in c:\users\257380\anaconda3\lib\site-packages (from speechrecognition) (4.1.1)
# Requirement already satisfied: comtypes in c:\users\257380\anaconda3\lib\site-packages (from pyttsx3) (1.1.10)
# Requirement already satisfied: pypiwin32 in c:\users\257380\anaconda3\lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in c:\users\257380\anaconda3\lib\site-packages (from pyttsx3) (302)
# Requirement already satisfied: requests in c:\users\257380\anaconda3\lib\site-packages (from wikipedia-api) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\257380\anaconda3\lib\site-packages (from requests->wikipedia-api) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\257380\anaconda3\lib\site-packages (from requests->wikipedia-api) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\257380\anaconda3\lib\site-packages (from requests->wikipedia-api) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\257380\anaconda3\lib\site-packages (from requests->wikipedia-api) (3.3)

# %%
# !pip install pipwin
# !pipwin install pyaudio
# Out:
# Collecting pipwin
#   Downloading pipwin-0.5.2.tar.gz (7.9 kB)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: requests in c:\users\257380\anaconda3\lib\site-packages (from pipwin) (2.27.1)
# Collecting pyprind
#   Downloading PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: six in c:\users\257380\anaconda3\lib\site-packages (from pipwin) (1.16.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in c:\users\257380\anaconda3\lib\site-packages (from pipwin) (4.11.1)
# Collecting js2py
#   Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: packaging in c:\users\257380\anaconda3\lib\site-packages (from pipwin) (21.3)
# Collecting pySmartDL>=1.3.1
#   Downloading pySmartDL-1.3.4-py3-none-any.whl (20 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\257380\anaconda3\lib\site-packages (from beautifulsoup4>=4.9.0->pipwin) (2.3.1)
# Collecting pyjsparser>=2.5.1
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
# Collecting tzlocal>=1.2
#   Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Collecting tzdata
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\257380\anaconda3\lib\site-packages (from packaging->pipwin) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\257380\anaconda3\lib\site-packages (from requests->pipwin) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\257380\anaconda3\lib\site-packages (from requests->pipwin) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\257380\anaconda3\lib\site-packages (from requests->pipwin) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\257380\anaconda3\lib\site-packages (from requests->pipwin) (3.3)
# Building wheels for collected packages: pipwin, docopt, pyjsparser
#   Building wheel for pipwin (setup.py): started
#   Building wheel for pipwin (setup.py): finished with status 'done'
#   Created wheel for pipwin: filename=pipwin-0.5.2-py2.py3-none-any.whl size=8790 sha256=3c2371ec52427ce07c2836722b2077f3b35c008d8096a85234cd0e971051dc30
#   Stored in directory: c:\users\257380\appdata\local\pip\cache\wheels\bc\86\30\f70db104d3f51560d9a177d6ced4f7e09f3e474d6985c101ae
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=f95238d835949013f4c99413226f4f16addf5b7de51ddd6161d498c37961c7ed
#   Stored in directory: c:\users\257380\appdata\local\pip\cache\wheels\70\4a\46\1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
#   Building wheel for pyjsparser (setup.py): started
#   Building wheel for pyjsparser (setup.py): finished with status 'done'
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=26000 sha256=b2123432490c1bc3360455e54f544767923d70f22abd4500075296c03a6cde14
#   Stored in directory: c:\users\257380\appdata\local\pip\cache\wheels\f0\70\61\f42dc45dcf0fbe8c495ce579b04730787081499bfb5b8bc60e
# Successfully built pipwin docopt pyjsparser
# Installing collected packages: tzdata, tzlocal, pyjsparser, pySmartDL, pyprind, js2py, docopt, pipwin
# Successfully installed docopt-0.6.2 js2py-0.74 pipwin-0.5.2 pySmartDL-1.3.4 pyjsparser-2.7.1 pyprind-2.11.3 tzdata-2025.2 tzlocal-5.3.1
# Building cache. Hang on . . .
# Traceback (most recent call last):
#   File "C:\Users\257380\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\257380\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\257380\anaconda3\Scripts\pipwin.exe\__main__.py", line 7, in <module>
#   File "C:\Users\257380\anaconda3\lib\site-packages\pipwin\command.py", line 84, in main
#     cache = pipwin.PipwinCache()
#   File "C:\Users\257380\anaconda3\lib\site-packages\pipwin\pipwin.py", line 210, in __init__
#     self.data = build_cache()
#   File "C:\Users\257380\anaconda3\lib\site-packages\pipwin\pipwin.py", line 103, in build_cache
#     dl_function = re.search(r"function dl.*\}", soup.find("script").string).group(0)
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
import speech_recognition as sr
import pyttsx3
import datetime
import wikipediaapi
import webbrowser
import os
import time
import subprocess

# %%
engine = pyttsx3.init()
def speak(audio):
    engine.say(audio)
    engine.runAndWait()

# %%
def wishMe():
    hour = int(datetime.datetime.now().hour)
    if 0 <= hour < 12:
        speak("Good Morning!")
    elif 12 <= hour < 18:
        speak("Good Afternoon!")
    else:
        speak("Good Evening!")
    speak("I am your assistant. How can I help you?")

# %%
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)

    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-in')
        print(f"User said: {query}\n")
    except Exception as e:
        print("Say that again please...")
        return "None"
    return query.lower()

# %%
def run_chatbot():
    wishMe()
    while True:
        query = takeCommand()

        if 'wikipedia' in query:
            speak('Searching Wikipedia...')
            wiki_wiki = wikipediaapi.Wikipedia('en')
            query = query.replace("wikipedia", "")
            page_py = wiki_wiki.page(query)
            speak("According to Wikipedia")
            print(page_py.summary[0:500])
            speak(page_py.summary[0:500])

        elif 'open google' in query:
            webbrowser.open("https://www.google.com")

        elif 'open youtube' in query:
            webbrowser.open("https://www.youtube.com")

        elif 'time' in query:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"The time is {strTime}")

        elif 'shutdown' in query:
            speak("Shutting down the system")
            os.system('shutdown /s /t 1')

        elif 'restart' in query:
            speak("Restarting the system")
            os.system('shutdown /r /t 1')

        elif 'exit' in query or 'stop' in query:
            speak("Goodbye!")
            break

        else:
            speak("I didn't understand that. Please say again.")

# %%
run_chatbot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\speech_recognition\__init__.py:103, in Microphone.get_pyaudio()
#     102 try:
# --> 103     import pyaudio
#     104 except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 run_chatbot()
#
# Input In [10], in run_chatbot()
#       2 wishMe()
#       3 while True:
# ----> 4     query = takeCommand()
#       6     if 'wikipedia' in query:
#       7         speak('Searching Wikipedia...')
#
# Input In [9], in takeCommand()
#       1 def takeCommand():
#       2     r = sr.Recognizer()
# ----> 3     with sr.Microphone() as source:
#       4         print("Listening...")
#       5         r.pause_threshold = 1
#
# File ~\anaconda3\lib\site-packages\speech_recognition\__init__.py:75, in Microphone.__init__(self, device_index, sample_rate, chunk_size)
#      72 assert isinstance(chunk_size, int) and chunk_size > 0, "Chunk size must be a positive integer"
#      74 # set up PyAudio
# ---> 75 self.pyaudio_module = self.get_pyaudio()
#      76 audio = self.pyaudio_module.PyAudio()
#      77 try:
#
# File ~\anaconda3\lib\site-packages\speech_recognition\__init__.py:105, in Microphone.get_pyaudio()
#     103     import pyaudio
#     104 except ImportError:
# --> 105     raise AttributeError("Could not find PyAudio; check installation")
#     106 return pyaudio
#
# AttributeError: Could not find PyAudio; check installation
